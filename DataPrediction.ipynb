# %%
import os
from math import sqrt
from numpy import concatenate, random
from matplotlib import pyplot as plt
from pandas import read_csv, DataFrame, to_datetime, concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM

random.seed(7)

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# Read dataset
file_path = 'Dataset Sensor Kel2.txt'  # Replace with your file path
dataset = read_csv(file_path, parse_dates={'datetime': ['Tanggal', 'Waktu']}, dayfirst=True, infer_datetime_format=True)
dataset['datetime'] = to_datetime(dataset['datetime'], format='%d/%m/%Y %H.%M.%S')
dataset['Bulan'] = dataset['datetime'].dt.month

# Select features for temperature and humidity
features_to_predict_temperature = ['Suhu (C)']
features_to_predict_humidity = ['Kelembaban']
# Normalize features using MinMaxScaler
scaler_temperature = MinMaxScaler(feature_range=(0, 1))
scaler_humidity = MinMaxScaler(feature_range=(0, 1))
scaled_values_temperature = scaler_temperature.fit_transform(dataset[features_to_predict_temperature])
scaled_values_humidity = scaler_humidity.fit_transform(dataset[features_to_predict_humidity])

# Prepare temperature dataset
#Reframing temperature data
reframed_temperature = series_to_supervised(scaled_values_temperature, 1, 1)
# Drop unnecessary coloumns
reframed_temperature.drop(reframed_temperature.columns[2:], axis=1, inplace=True)
# split data menjadi set pelatihan dan pengujian
values_temperature = reframed_temperature.values
n_train_temperature = int(len(dataset) * 0.75)
train_temperature = values_temperature[:n_train_temperature, :]
test_temperature = values_temperature[n_train_temperature:, :]
# Pemisahan input(X) dan output(Y)
train_x_temperature, train_y_temperature = train_temperature[:, :-1], train_temperature[:, -1]
test_x_temperature, test_y_temperature = test_temperature[:, :-1], test_temperature[:, -1]
# Reshape data untuk model LSTM
train_x_temperature = train_x_temperature.reshape((train_x_temperature.shape[0], 1, train_x_temperature.shape[1]))
test_x_temperature = test_x_temperature.reshape((test_x_temperature.shape[0], 1, test_x_temperature.shape[1]))

# Design and train LSTM model for temperature
model_temperature = Sequential()
model_temperature.add(LSTM(150, input_shape=(train_x_temperature.shape[1], train_x_temperature.shape[2])))
model_temperature.add(Dense(units=1))
model_temperature.compile(loss='mae', optimizer='adam')
history_temperature = model_temperature.fit(train_x_temperature, train_y_temperature, epochs=100, batch_size=32,
                                           validation_data=(test_x_temperature, test_y_temperature), verbose=1, shuffle=False)

# Make predictions for temperature
yhat_train_temperature = model_temperature.predict(train_x_temperature)
# Transformasi Invers pada Prediksi Pelatihan
train_x_temperature = train_x_temperature.reshape((train_x_temperature.shape[0], train_x_temperature.shape[2]))
inv_yhat_train_temperature = scaler_temperature.inverse_transform(
    concatenate((yhat_train_temperature, train_x_temperature[:, 1:]), axis=1))
inv_yhat_train_temperature = inv_yhat_train_temperature[:, 0]
# Transformasi Invers pada Label Pelatihan
train_y_temperature = train_y_temperature.reshape((len(train_y_temperature), 1))
inv_y_train_temperature = scaler_temperature.inverse_transform(
    concatenate((train_y_temperature, train_x_temperature[:, 1:]), axis=1))
inv_y_train_temperature = inv_y_train_temperature[:, 0]
# prediksi pada data pengujian
yhat_test_temperature = model_temperature.predict(test_x_temperature)
# transformasi inverse pada prediksi pengujian
test_x_temperature = test_x_temperature.reshape((test_x_temperature.shape[0], test_x_temperature.shape[2]))
inv_yhat_test_temperature = scaler_temperature.inverse_transform(
    concatenate((yhat_test_temperature, test_x_temperature[:, 1:]), axis=1))
inv_yhat_test_temperature = inv_yhat_test_temperature[:, 0]
# transformasi inverse pada label pengujian
test_y_temperature = test_y_temperature.reshape((len(test_y_temperature), 1))
inv_y_test_temperature = scaler_temperature.inverse_transform(
    concatenate((test_y_temperature, test_x_temperature[:, 1:]), axis=1))
inv_y_test_temperature = inv_y_test_temperature[:, 0]

# Prepare humidity dataset
reframed_humidity = series_to_supervised(scaled_values_humidity, 1, 1)
reframed_humidity.drop(reframed_humidity.columns[2:], axis=1, inplace=True)
values_humidity = reframed_humidity.values
n_train_humidity = int(len(dataset) * 0.75)
train_humidity = values_humidity[:n_train_humidity, :]
test_humidity = values_humidity[n_train_humidity:, :]
train_x_humidity, train_y_humidity = train_humidity[:, :-1], train_humidity[:, -1]
test_x_humidity, test_y_humidity = test_humidity[:, :-1], test_humidity[:, -1]
train_x_humidity = train_x_humidity.reshape((train_x_humidity.shape[0], 1, train_x_humidity.shape[1]))
test_x_humidity = test_x_humidity.reshape((test_x_humidity.shape[0], 1, test_x_humidity.shape[1]))

# Design and train LSTM model for humidity
model_humidity = Sequential()
model_humidity.add(LSTM(150, input_shape=(train_x_humidity.shape[1], train_x_humidity.shape[2])))
model_humidity.add(Dense(units=1))
model_humidity.compile(loss='mae', optimizer='adam')
history_humidity = model_humidity.fit(train_x_humidity, train_y_humidity, epochs=100, batch_size=32,
                                      validation_data=(test_x_humidity, test_y_humidity), verbose=1, shuffle=False)

# Make predictions for humidity
yhat_train_humidity = model_humidity.predict(train_x_humidity)
train_x_humidity = train_x_humidity.reshape((train_x_humidity.shape[0], train_x_humidity.shape[2]))
inv_yhat_train_humidity = scaler_humidity.inverse_transform(
    concatenate((yhat_train_humidity, train_x_humidity[:, 1:]), axis=1))
inv_yhat_train_humidity = inv_yhat_train_humidity[:, 0]
train_y_humidity = train_y_humidity.reshape((len(train_y_humidity), 1))
inv_y_train_humidity = scaler_humidity.inverse_transform(
    concatenate((train_y_humidity, train_x_humidity[:, 1:]), axis=1))
inv_y_train_humidity = inv_y_train_humidity[:, 0]

yhat_test_humidity = model_humidity.predict(test_x_humidity)
test_x_humidity = test_x_humidity.reshape((test_x_humidity.shape[0], test_x_humidity.shape[2]))
inv_yhat_test_humidity = scaler_humidity.inverse_transform(
    concatenate((yhat_test_humidity, test_x_humidity[:, 1:]), axis=1))
inv_yhat_test_humidity = inv_yhat_test_humidity[:, 0]
test_y_humidity = test_y_humidity.reshape((len(test_y_humidity), 1))
inv_y_test_humidity = scaler_humidity.inverse_transform(
    concatenate((test_y_humidity, test_x_humidity[:, 1:]), axis=1))
inv_y_test_humidity = inv_y_test_humidity[:, 0]

# Plot Model Loss for temperature
plt.figure(figsize=(10, 5))
plt.plot(history_temperature.history['loss'], label='Temperature Training Loss')
plt.plot(history_temperature.history['val_loss'], label='Temperature Validation Loss')
plt.title('Temperature Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot Model Loss for humidity
plt.figure(figsize=(10, 5))
plt.plot(history_humidity.history['loss'], label='Humidity Training Loss')
plt.plot(history_humidity.history['val_loss'], label='Humidity Validation Loss')
plt.title('Humidity Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Calculate RMSE for temperature and humidity
rmse_train_temperature = sqrt(mean_squared_error(inv_y_train_temperature, inv_yhat_train_temperature))
print('Temperature Train RMSE: %.3f' % rmse_train_temperature)

rmse_test_temperature = sqrt(mean_squared_error(inv_y_test_temperature, inv_yhat_test_temperature))
print('Temperature Test RMSE: %.3f' % rmse_test_temperature)

rmse_train_humidity = sqrt(mean_squared_error(inv_y_train_humidity, inv_yhat_train_humidity))
print('Humidity Train RMSE: %.3f' % rmse_train_humidity)

rmse_test_humidity = sqrt(mean_squared_error(inv_y_test_humidity, inv_yhat_test_humidity))
print('Humidity Test RMSE: %.3f' % rmse_test_humidity)


# Plot the results for temperature
x0_temperature = list(range(len(train_y_temperature)))
x1_temperature = list(range(len(train_y_temperature), len(train_y_temperature) + len(test_y_temperature)))

fig_temperature, (ax1_temperature, ax2_temperature) = plt.subplots(2, 1, sharex=True, figsize=(10, 8))

# Plot for Suhu (C)
ax1_temperature.plot(dataset['datetime'], dataset['Suhu (C)'], 'b', label='Actual Suhu (C)')
ax1_temperature.plot(dataset['datetime'].iloc[x1_temperature], inv_yhat_test_temperature, 'r', label='Predicted Suhu (C)')
ax1_temperature.set_ylabel('Suhu (C)')
ax1_temperature.set_xlabel('Tanggal')
ax1_temperature.set_title('Prediksi Suhu (C)')
ax1_temperature.legend()

# Plot for Kelembaban
ax2_temperature.plot(dataset['datetime'], dataset['Kelembaban'], 'b', label='Actual Kelembaban')
ax2_temperature.plot(dataset['datetime'].iloc[x1_temperature], inv_yhat_test_humidity, 'r', label='Predicted Kelembaban')
ax2_temperature.set_ylabel('Kelembaban')
ax2_temperature.set_xlabel('Tanggal')
ax2_temperature.set_title('Prediksi Kelembaban')
ax2_temperature.legend()

ax1_temperature.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d-%m'))
ax2_temperature.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%d-%m'))

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\HP\AppData\Local\Temp\ipykernel_15400\442795106.py:39: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dataset = read_csv(file_path, parse_dates={'datetime': ['Tanggal', 'Waktu']}, dayfirst=True, infer_datetime_format=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_15400\442795106.py:39: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset = read_csv(file_path, parse_dates={'datetime': ['Tanggal', 'Waktu']}, dayfirst=True, infer_datetime_format=True)
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 228/228 [==============================] - 9s 14ms/step - loss: 0.1390 - val_loss: 0.0165
# Epoch 2/100
# 228/228 [==============================] - 3s 12ms/step - loss: 0.0120 - val_loss: 0.0166
# Epoch 3/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0129 - val_loss: 0.0115
# Epoch 4/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0126 - val_loss: 0.0099
# Epoch 5/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0117 - val_loss: 0.0155
# Epoch 6/100
# 228/228 [==============================] - 3s 12ms/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 7/100
# 228/228 [==============================] - 3s 12ms/step - loss: 0.0120 - val_loss: 0.0088
# Epoch 8/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0113 - val_loss: 0.0090
# Epoch 9/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0109 - val_loss: 0.0116
# Epoch 10/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0107 - val_loss: 0.0086
# Epoch 11/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 0.0142
# Epoch 12/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 13/100
# 228/228 [==============================] - 3s 13ms/step - loss: 0.0103 - val_loss: 0.0089
# Epoch 14/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 15/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0097 - val_loss: 0.0104
# Epoch 16/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0094 - val_loss: 0.0094
# Epoch 17/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0100 - val_loss: 0.0084
# Epoch 18/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 19/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0094 - val_loss: 0.0075
# Epoch 20/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0098 - val_loss: 0.0067
# Epoch 21/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0093 - val_loss: 0.0069
# Epoch 22/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0098 - val_loss: 0.0078
# Epoch 23/100
# 228/228 [==============================] - 3s 13ms/step - loss: 0.0090 - val_loss: 0.0065
# Epoch 24/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0093 - val_loss: 0.0081
# Epoch 25/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0093 - val_loss: 0.0087
# Epoch 26/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0088 - val_loss: 0.0085
# Epoch 27/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0093
# Epoch 28/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0094 - val_loss: 0.0090
# Epoch 29/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0087 - val_loss: 0.0063
# Epoch 30/100
# 228/228 [==============================] - 3s 12ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 31/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 0.0050
# Epoch 32/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0076 - val_loss: 0.0056
# Epoch 33/100
# 228/228 [==============================] - 3s 12ms/step - loss: 0.0071 - val_loss: 0.0055
# Epoch 34/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 35/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0076 - val_loss: 0.0052
# Epoch 36/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0075 - val_loss: 0.0119
# Epoch 37/100
# 228/228 [==============================] - 3s 12ms/step - loss: 0.0079 - val_loss: 0.0054
# Epoch 38/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 39/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 40/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0062 - val_loss: 0.0042
# Epoch 41/100
# 228/228 [==============================] - 3s 13ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 42/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0062 - val_loss: 0.0049
# Epoch 43/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0039
# Epoch 44/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0052 - val_loss: 0.0078
# Epoch 45/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 46/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 47/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 48/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0060 - val_loss: 0.0039
# Epoch 49/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 50/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 51/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 52/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 53/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 54/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 55/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 56/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 57/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 58/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 59/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 60/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 61/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 62/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0047 - val_loss: 0.0067
# Epoch 63/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 64/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 65/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0048 - val_loss: 0.0041
# Epoch 66/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 67/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0045 - val_loss: 0.0030
# Epoch 68/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 69/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 70/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0045 - val_loss: 0.0028
# Epoch 71/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0047 - val_loss: 0.0028
# Epoch 72/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 73/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 74/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0047 - val_loss: 0.0031
# Epoch 75/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 76/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 77/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 78/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 79/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 80/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 81/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 82/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 83/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0064
# Epoch 84/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 85/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 86/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0034
# Epoch 87/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0047 - val_loss: 0.0065
# Epoch 88/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 89/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0049 - val_loss: 0.0097
# Epoch 90/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 91/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 92/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 93/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 94/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 95/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 96/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 97/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 98/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 99/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0028
# Epoch 100/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0048 - val_loss: 0.0065
# 228/228 [==============================] - 2s 3ms/step
# 76/76 [==============================] - 0s 4ms/step
# Epoch 1/100
# 228/228 [==============================] - 7s 14ms/step - loss: 0.1377 - val_loss: 0.0272
# Epoch 2/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0289 - val_loss: 0.0254
# Epoch 3/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0276 - val_loss: 0.0217
# Epoch 4/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0250 - val_loss: 0.0221
# Epoch 5/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0239 - val_loss: 0.0205
# Epoch 6/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0228 - val_loss: 0.0192
# Epoch 7/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0214 - val_loss: 0.0153
# Epoch 8/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0207 - val_loss: 0.0112
# Epoch 9/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0183 - val_loss: 0.0110
# Epoch 10/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0150 - val_loss: 0.0121
# Epoch 11/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0139 - val_loss: 0.0105
# Epoch 12/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0121 - val_loss: 0.0075
# Epoch 13/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 0.0066
# Epoch 14/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0093 - val_loss: 0.0047
# Epoch 15/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0080 - val_loss: 0.0047
# Epoch 16/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0072 - val_loss: 0.0037
# Epoch 17/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0033
# Epoch 18/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 19/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 20/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 21/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 22/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0064 - val_loss: 0.0047
# Epoch 23/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 24/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0069 - val_loss: 0.0039
# Epoch 25/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 26/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 27/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 28/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 29/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0071 - val_loss: 0.0037
# Epoch 30/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 31/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0041
# Epoch 32/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 33/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0037
# Epoch 34/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0033
# Epoch 35/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 36/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0072 - val_loss: 0.0054
# Epoch 37/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 38/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 39/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0068 - val_loss: 0.0035
# Epoch 40/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0067 - val_loss: 0.0039
# Epoch 41/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0041
# Epoch 42/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0063 - val_loss: 0.0048
# Epoch 43/100
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 44/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0034
# Epoch 45/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0065 - val_loss: 0.0073
# Epoch 46/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 47/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 0.0038
# Epoch 48/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 49/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0064 - val_loss: 0.0094
# Epoch 50/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0070 - val_loss: 0.0047
# Epoch 51/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0062 - val_loss: 0.0046
# Epoch 52/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 53/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 54/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 55/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0067 - val_loss: 0.0033
# Epoch 56/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 57/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0065 - val_loss: 0.0041
# Epoch 58/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 59/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 60/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 61/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0060 - val_loss: 0.0038
# Epoch 62/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0037
# Epoch 63/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 64/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0064 - val_loss: 0.0050
# Epoch 65/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0040
# Epoch 66/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0061 - val_loss: 0.0045
# Epoch 67/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0065 - val_loss: 0.0048
# Epoch 68/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 69/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 70/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 71/100
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 72/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 73/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0047
# Epoch 74/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0059 - val_loss: 0.0053
# Epoch 75/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 76/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0060 - val_loss: 0.0076
# Epoch 77/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 78/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 79/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 80/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0066 - val_loss: 0.0033
# Epoch 81/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 82/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0064 - val_loss: 0.0039
# Epoch 83/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 84/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 85/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0067 - val_loss: 0.0035
# Epoch 86/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 87/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 88/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 89/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0068 - val_loss: 0.0042
# Epoch 90/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 91/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0063 - val_loss: 0.0036
# Epoch 92/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 93/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0067 - val_loss: 0.0033
# Epoch 94/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0062 - val_loss: 0.0033
# Epoch 95/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 96/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 97/100
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 0.0046
# Epoch 98/100
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0065 - val_loss: 0.0042
# Epoch 99/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0034
# Epoch 100/100
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0048
# 228/228 [==============================] - 2s 4ms/step
# 76/76 [==============================] - 0s 4ms/step
# Temperature Train RMSE: 0.547
# Temperature Test RMSE: 0.292
# Humidity Train RMSE: 1.538
# Humidity Test RMSE: 0.709
